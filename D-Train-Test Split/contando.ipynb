# %%
import pandas as pd

# Read the CSV files
model1test = pd.read_csv('/Users/marcelosilva/Desktop/early-obesity-prediction/D-Train-Test Split/MODEL1TEST.csv')
model2test = pd.read_csv('/Users/marcelosilva/Desktop/early-obesity-prediction/D-Train-Test Split/MODEL2TEST.csv')
model3test = pd.read_csv('/Users/marcelosilva/Desktop/early-obesity-prediction/D-Train-Test Split/MODEL3TEST.csv')

# Count columns in each dataset
print(f"MODEL1TEST columns: {len(model1test.columns)}")
print(f"MODEL2TEST columns: {len(model2test.columns)}")
print(f"MODEL3TEST columns: {len(model3test.columns)}")
# Out:
# MODEL1TEST columns: 32
# MODEL2TEST columns: 22
# MODEL3TEST columns: 49
