# %%
import pandas as pd


df_original = pd.read_csv('/Users/marcelosilva/Desktop/projectOne/5/A-TrainTestDataset/TrainDS.csv')

df_binary = pd.read_csv('/Users/marcelosilva/Desktop/projectOne/6/B- Binary Target DS DT/DatasetTrain.csv')

# %%
# No dataset original (4 classes)
df_original['status_nutricional_who'].value_counts()

# No dataset binário atual
df_binary['status_nutricional_who'].value_counts()
# Out:
# 0    2580
# 1     849
# Name: status_nutricional_who, dtype: int64
