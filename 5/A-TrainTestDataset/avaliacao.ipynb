# %%
import pandas as pd

testDS = pd.read_csv('/Users/marcelosilva/Desktop/projectOne/5/A-TrainTestDataset/TestDS.csv')
trainDS = pd.read_csv('/Users/marcelosilva/Desktop/projectOne/5/A-TrainTestDataset/TrainDS.csv')

print("Test Dataset Shape:", testDS.shape)
print("Train Dataset Shape:", trainDS.shape)
# Out:
# Test Dataset Shape: (644, 39)
# Train Dataset Shape: (3643, 39)
